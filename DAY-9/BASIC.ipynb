# %%
import numpy as np

# %%
numbers = np.array(
    [10, 20, 30, 40]
)

print(numbers)
# Out:
# [10 20 30 40]

# %%
type(numbers)
# Out:
# numpy.ndarray

# %%
arr = np.array(
    [1, 2, 3, 4]
)

# %%
arr + 5
# Out:
# array([6, 7, 8, 9])

# %%
arr * 2
# Out:
# array([2, 4, 6, 8])

# %%
arr ** 2
# Out:
# array([ 1,  4,  9, 16])

# %%
data = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

# %%
data.shape
# Out:
# (2, 3)

# %%
expenses = np.array(
    [120, 200, 350, 100]
)

# %%
np.sum(expenses)
# Out:
# np.int64(770)

# %%
np.mean(expenses)
# Out:
# np.float64(192.5)

# %%
np.max(expenses)
# Out:
# np.int64(350)

# %%
np.min(expenses)
# Out:
# np.int64(100)
